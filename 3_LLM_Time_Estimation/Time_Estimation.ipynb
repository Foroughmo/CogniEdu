# %% [markdown]
# # Assignment Time Estimation

# %% [markdown]
# # 1. Generate Data

# %% [markdown]
# ### 1.1 Generate Assignment Content

# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import os
import io
import re
import requests
import vertexai
import PyPDF2
from google.cloud import storage

# %% [markdown]
# #### Notebook Environment

# %%
PROJECT_ID = ""
LOCATION = ""

vertexai.init(project=PROJECT_ID, location=LOCATION)

# %% [markdown]
# #### GCS Bucket

# %%
bucket_name = ''
folder_name = ''

# %%
# Function to Load PDF Content from GCS and Clean It
def load_pdf_from_gcs(bucket_name, blob_name):
    """Load PDF content from Google Cloud Storage and clean it."""
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(blob_name)
    
    # Download the Blob's Content as Bytes
    pdf_content = blob.download_as_bytes()
    
    # Use PyPDF2 to Extract Text from the PDF cCntent
    pdf_reader = PyPDF2.PdfReader(io.BytesIO(pdf_content))
    text_content = ""
    for page_num in range(len(pdf_reader.pages)):
        page_text = pdf_reader.pages[page_num].extract_text()
        text_content += " " + page_text.strip() if page_text else ""
    
    # Clean Text
    text_content = " ".join(text_content.split())
    
    # Remove Special Characters While Preserving Words
    text_content = re.sub(r'(\b\w*)\W+(\w*\b)', r'\1 \2', text_content)
    text_content = " ".join(text_content.split())
    
    return text_content

# %% [markdown]
# #### Extract Information from PDFs

# %%
# Function to Extract Course Name and Assignment Name from Filename
def extract_names(file_name):
    """Extract course name and assignment name from filename."""
    parts = filename.split('_')
    if len(parts) >= 3:
        if filename.startswith("Marketing_Analytics"):
            course_name = "Marketing Analytics"
            remaining_parts = parts[2:]
        elif filename.startswith("Statistical_Analysis"):
            course_name = "Statistical Analysis"
            remaining_parts = parts[2:]
        elif filename.startswith("Introduction_to_Art_History"):
            course_name = "Introduction to Art History"
            remaining_parts = parts[4:]
        else:
            course_name = "Unknown Course"
            remaining_parts = parts
        assignment_name = parts[-2] + ' ' + parts[-1].split('.')[0]
        return course_name, assignment_name
    else:
        return None, None

# %%
filenames = [
    'Introduction_to_Art_History_Week_1_Assignment_1.pdf',
    'Introduction_to_Art_History_Week_2_Assignment_2.pdf',
    'Introduction_to_Art_History_Week_3_Assignment_3.pdf',
    'Marketing_Analytics_Week_1_Assignment_1.pdf',
    'Marketing_Analytics_Week_2_Assignment_2.pdf',
    'Marketing_Analytics_Week_3_Assignment_3.pdf',
    'Marketing_Analytics_Week_4_Assignment_4.pdf',
    'Statistical_Analysis_Week_1_Assignment_1.pdf',
    'Statistical_Analysis_Week_2_Assignment_2.pdf',
    'Statistical_Analysis_Week_3_Assignment_3.pdf',
    'Statistical_Analysis_Week_4_Assignment_4.pdf'
        ]

# %%
docs = []
course_names = []
assignment_names = []

# List and Process Specified Files in the Folder
storage_client = storage.Client()
for filename in filenames:
    blob_name = f'{folder_name}/{filename}'
    try:
        pdf_content = load_pdf_from_gcs(bucket_name, blob_name)
        course_name, assignment_name = extract_names(filename)
        if course_name and assignment_name:
            docs.append(pdf_content)
            course_names.append(course_name)
            assignment_names.append(assignment_name)
            print(f'Successfully Loaded and Cleaned: {filename}')
    except Exception as e:
        print(f'Error Loading {filename}: {e}')

# Create DataFrame
data = {
    'Assignment Name': assignment_names,
    'Course Name': course_names,
    'Content': docs
}

df = pd.DataFrame(data)
df.head()
# Out:
# Successfully Loaded and Cleaned: Introduction_to_Art_History_Week_1_Assignment_1.pdf
# Successfully Loaded and Cleaned: Introduction_to_Art_History_Week_2_Assignment_2.pdf
# Successfully Loaded and Cleaned: Introduction_to_Art_History_Week_3_Assignment_3.pdf
# Successfully Loaded and Cleaned: Marketing_Analytics_Week_1_Assignment_1.pdf
# Successfully Loaded and Cleaned: Marketing_Analytics_Week_2_Assignment_2.pdf
# Successfully Loaded and Cleaned: Marketing_Analytics_Week_3_Assignment_3.pdf
# Successfully Loaded and Cleaned: Marketing_Analytics_Week_4_Assignment_4.pdf
# Successfully Loaded and Cleaned: Statistical_Analysis_Week_1_Assignment_1.pdf
# Successfully Loaded and Cleaned: Statistical_Analysis_Week_2_Assignment_2.pdf
# Successfully Loaded and Cleaned: Statistical_Analysis_Week_3_Assignment_3.pdf
# Successfully Loaded and Cleaned: Statistical_Analysis_Week_4_Assignment_4.pdf
#   Assignment Name                  Course Name  \
# 0    Assignment 1  Introduction to Art History
# 1    Assignment 2  Introduction to Art History
# 2    Assignment 3  Introduction to Art History
# 3    Assignment 1          Marketing Analytics
# 4    Assignment 2          Marketing Analytics
#
#                                              Content
# 0  Introduc on to Art History Assignment 1 Early ...
# 1  Introduc on to Art History Assignment 2 Classi...
# 2  Introduc on to Art History Assignment 3 The Mi...
# 3  Marketing Analytics Assignment 1 Introduc on W...
# 4  Marketing Analytics Assignment 2 Introduc on W...

# %%
# Preview of Data in Content Column
df['Content'].iloc[0]
# Out:
# 'Introduc on to Art History Assignment 1 Early Civiliza ons and their Art Explore the art of early civilizations such as Mesopotamia Egypt and the Indus Valley Discuss the signi icance of art in these cultures and how it re lects their beliefs values and social structures Ques ons 1 Describe the key features of Mesopotamian art How did it re lect their religious beliefs 2 What are the main characteristics of Egyptian art Discuss the role of art in Egyptian burial practices 3 Compare and contrast the art of the Indus Valley with that of Mesopotamia and Egypt.'

# %% [markdown]
# ### 1.2 Generate Data ( user info )

# %%
# Import Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error

import vertexai
from google.cloud import aiplatform
from vertexai.generative_models import GenerativeModel, ChatSession, Part
import vertexai.preview.generative_models as generative_models

# %%
# Define conditions and corresponding assignment types
conditions = [
    df['Course Name'] == 'Introduction to Art History',
    df['Course Name'] == 'Statistical Analysis',  
    df['Course Name'] == 'Marketing Analytics'
]

choices = ['Essay', 'Problem Set', 'Coding']
# Create new column 
df['Assignment Type'] = np.select(conditions, choices, default=np.nan)
df
# Out:
#    Assignment Name                  Course Name  \
# 0     Assignment 1  Introduction to Art History
# 1     Assignment 2  Introduction to Art History
# 2     Assignment 3  Introduction to Art History
# 3     Assignment 1          Marketing Analytics
# 4     Assignment 2          Marketing Analytics
# 5     Assignment 3          Marketing Analytics
# 6     Assignment 4          Marketing Analytics
# 7     Assignment 1         Statistical Analysis
# 8     Assignment 2         Statistical Analysis
# 9     Assignment 3         Statistical Analysis
# 10    Assignment 4         Statistical Analysis
#
#                                               Content Assignment Type
# 0   Introduc on to Art History Assignment 1 Early ...           Essay
# 1   Introduc on to Art History Assignment 2 Classi...           Essay
# 2   Introduc on to Art History Assignment 3 The Mi...           Essay
# 3   Marketing Analytics Assignment 1 Introduc on W...          Coding
# 4   Marketing Analytics Assignment 2 Introduc on W...          Coding
# 5   Marketing Analytics Assignment 3 Introduc on W...          Coding
# 6   Marketing Analytics Assignment 4 Introduc on W...          Coding
# 7   Statistical Analysis Assignment 1 Objec ve Und...     Problem Set
# 8   Statistical Analysis Assignment 2 Objec ve Exp...     Problem Set
# 9   Statistical Analysis Assignment 3 Objec ve Lea...     Problem Set
# 10  Statistical Analysis Assignment 4 Objec ve Und...     Problem Set

# %%
len(df)
# Out:
# 11

# %%
df['Difficulty_Level'] = np.nan
df
# Out:
#    Assignment Name                  Course Name  \
# 0     Assignment 1  Introduction to Art History
# 1     Assignment 2  Introduction to Art History
# 2     Assignment 3  Introduction to Art History
# 3     Assignment 1          Marketing Analytics
# 4     Assignment 2          Marketing Analytics
# 5     Assignment 3          Marketing Analytics
# 6     Assignment 4          Marketing Analytics
# 7     Assignment 1         Statistical Analysis
# 8     Assignment 2         Statistical Analysis
# 9     Assignment 3         Statistical Analysis
# 10    Assignment 4         Statistical Analysis
#
#                                               Content Assignment Type  \
# 0   Introduc on to Art History Assignment 1 Early ...           Essay
# 1   Introduc on to Art History Assignment 2 Classi...           Essay
# 2   Introduc on to Art History Assignment 3 The Mi...           Essay
# 3   Marketing Analytics Assignment 1 Introduc on W...          Coding
# 4   Marketing Analytics Assignment 2 Introduc on W...          Coding
# 5   Marketing Analytics Assignment 3 Introduc on W...          Coding
# 6   Marketing Analytics Assignment 4 Introduc on W...          Coding
# 7   Statistical Analysis Assignment 1 Objec ve Und...     Problem Set
# 8   Statistical Analysis Assignment 2 Objec ve Exp...     Problem Set
# 9   Statistical Analysis Assignment 3 Objec ve Lea...     Problem Set
# 10  Statistical Analysis Assignment 4 Objec ve Und...     Problem Set
#
#     Difficulty_Level
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
# 10               NaN

# %% [markdown]
# # LLM to generate assignment difficulty level

# %%
model = GenerativeModel("gemini-1.0-pro-002")

# %% [markdown]
# ###  Assignment Difficulty Level

# %%
def get_llm_response(input_text, temperature=0.1):
    responses = model.generate_content(
        [input_text],
        generation_config={
            "max_output_tokens": 2048,
            "temperature": temperature,
            "top_p": 1
        },
        stream=True,
    )
    
    full_response = ""
    for response in responses:
        full_response += response.text
        print(response.text, end="")
    
    return full_response


def process_assignments(df):
    # Group assignments by course
    grouped_assignments = df.groupby('Course Name')
    
    all_difficulties = {}
    
    for course, group in grouped_assignments:
        assignments = group['Content'].tolist()
        assignment_names = group['Assignment Name'].tolist()
        
        # Create a list of assignment descriptions
        assignment_descriptions = [f"{name}: {content}" for name, content in zip(assignment_names, assignments)]
        
        prompt = f"""
        For the course '{course}', evaluate the difficulty level of each assignment based on the following descriptions:

        {'. '.join(assignment_descriptions)}

        Assign a difficulty level (Easy, Medium, or Hard) to each assignment. Here is an example of how to assign difficulty level to each assignment:
        
        This is an example of an easy assignment: 
        
        Assignment: Introduction to Art History - Easy Level

        Title: Understanding Renaissance Art
        Objective:  
        Introduce students to Renaissance art by analyzing a famous artwork.

        Instructions:
        1. Choose an Artwork: Select one of the following:
           - "Mona Lisa" by Leonardo da Vinci
           - "The Last Supper" by Leonardo da Vinci
           - "The School of Athens" by Raphael
           - "The Birth of Venus" by Sandro Botticelli

        2. Research: Use at least two credible sources for information.

        3. Write a 500-word Essay: Include:
           - Introduction: Artist, title, and creation date.
           - Description: Subject matter, composition, color, techniques.
           - Historical Context: Significance and reflection of Renaissance values.
           - Personal Reflection: Personal thoughts and feelings about the artwork.

        4. Submission: Submit as a PDF via Canvas by [due date].
        
        Here is another example for marketing analytics with difficulty level of hard :
        Assignment: Marketing Analytics - Hard Level

        Title: Advanced Customer Segmentation Analysis

        Objective:  Conduct a detailed customer segmentation analysis using advanced clustering techniques to identify distinct customer groups and provide strategic marketing insights.

        Instructions:

        1. Dataset: Use the provided dataset with customer purchase history, demographics, and engagement metrics.

        2. Data Preprocessing: Clean and preprocess the data, handle missing values, and normalize the data.

        3. Clustering Analysis: Apply at least two clustering algorithms (e.g., K-Means, Hierarchical Clustering), and determine the optimal number of clusters using methods like the Elbow Method and Silhouette Score.

        4. Segmentation Analysis:Analyze and interpret the resulting clusters, profiling each segment based on key attributes.

        5. Strategic Insights: Provide actionable marketing strategies and personalized campaigns for each segment.

        6. Report (1500 words max): Include an introduction, methodology, results with visualizations, and recommendations. Submit the report and code/script as a ZIP file via Canvas by [due date].

        
        Format your response as follows:
        * **Assignment X:** Difficulty

        Only provide the difficulty levels, no additional explanation.
        """
        
        llm_response = get_llm_response(prompt)
        
        # Check if the response is valid
        if not llm_response:
            print(f"Warning: No valid response received for course '{course}'. Skipping.")
            continue
        
        # Parse the LLM response
        difficulty_map = {'Easy': 1, 'Medium': 2, 'Hard': 3}
        course_difficulties = {}
        
        for line in llm_response.split('\n'):
            line = line.strip()
            match = re.search(r'\*\*Assignment (\d+):\*\* (\w+)', line)
            if match:
                assignment_num, difficulty = match.groups()
                assignment_name = f"Assignment {assignment_num}"
                course_difficulties[assignment_name] = difficulty_map.get(difficulty.strip(), float('nan'))
        
        all_difficulties[course] = course_difficulties
        print(f"Parsed difficulties for {course}:", course_difficulties)  # Debugging line
    
    # Apply difficulties to the DataFrame
    df['Difficulty_Level'] = df.apply(
        lambda row: all_difficulties.get(row['Course Name'], {}).get(row['Assignment Name'], float('nan')),
        axis=1
    )
    
    return df

# Use the function
df = process_assignments(df)
print(df[['Course Name', 'Assignment Name', 'Difficulty_Level']])
# Out:
# ## Difficulty Levels for Introduction to Art History Assignments:
#
# **Assignment 1:** Medium
# **Assignment 2:** Medium
# **Assignment 3:** Hard
# Parsed difficulties for Introduction to Art History: {'Assignment 1': 2, 'Assignment 2': 2, 'Assignment 3': 3}
# ## Difficulty Levels for Marketing Analytics Assignments:
#
# * **Assignment 1:** Medium
# * **Assignment 2:** Hard
# * **Assignment 3:** Hard
# * **Assignment 4:** Hard
# Parsed difficulties for Marketing Analytics: {'Assignment 1': 2, 'Assignment 2': 3, 'Assignment 3': 3, 'Assignment 4': 3}
# ## Difficulty Levels for Statistical Analysis Assignments:
#
# * **Assignment 1:** Easy
# * **Assignment 2:** Medium
# * **Assignment 3:** Hard
# * **Assignment 4:** Medium
# Parsed difficulties for Statistical Analysis: {'Assignment 1': 1, 'Assignment 2': 2, 'Assignment 3': 3, 'Assignment 4': 2}
#                     Course Name Assignment Name  Difficulty_Level
# 0   Introduction to Art History    Assignment 1                 2
# 1   Introduction to Art History    Assignment 2                 2
# 2   Introduction to Art History    Assignment 3                 3
# 3           Marketing Analytics    Assignment 1                 2
# 4           Marketing Analytics    Assignment 2                 3
# 5           Marketing Analytics    Assignment 3                 3
# 6           Marketing Analytics    Assignment 4                 3
# 7          Statistical Analysis    Assignment 1                 1
# 8          Statistical Analysis    Assignment 2                 2
# 9          Statistical Analysis    Assignment 3                 3
# 10         Statistical Analysis    Assignment 4                 2

# %%
df
# Out:
#    Assignment Name                  Course Name  \
# 0     Assignment 1  Introduction to Art History
# 1     Assignment 2  Introduction to Art History
# 2     Assignment 3  Introduction to Art History
# 3     Assignment 1          Marketing Analytics
# 4     Assignment 2          Marketing Analytics
# 5     Assignment 3          Marketing Analytics
# 6     Assignment 4          Marketing Analytics
# 7     Assignment 1         Statistical Analysis
# 8     Assignment 2         Statistical Analysis
# 9     Assignment 3         Statistical Analysis
# 10    Assignment 4         Statistical Analysis
#
#                                               Content Assignment Type  \
# 0   Introduc on to Art History Assignment 1 Early ...           Essay
# 1   Introduc on to Art History Assignment 2 Classi...           Essay
# 2   Introduc on to Art History Assignment 3 The Mi...           Essay
# 3   Marketing Analytics Assignment 1 Introduc on W...          Coding
# 4   Marketing Analytics Assignment 2 Introduc on W...          Coding
# 5   Marketing Analytics Assignment 3 Introduc on W...          Coding
# 6   Marketing Analytics Assignment 4 Introduc on W...          Coding
# 7   Statistical Analysis Assignment 1 Objec ve Und...     Problem Set
# 8   Statistical Analysis Assignment 2 Objec ve Exp...     Problem Set
# 9   Statistical Analysis Assignment 3 Objec ve Lea...     Problem Set
# 10  Statistical Analysis Assignment 4 Objec ve Und...     Problem Set
#
#     Difficulty_Level
# 0                  2
# 1                  2
# 2                  3
# 3                  2
# 4                  3
# 5                  3
# 6                  3
# 7                  1
# 8                  2
# 9                  3
# 10                 2

# %% [markdown]
# ### Predicting Time with LLM

# %%
df.iloc[1]
# Out:
# Assignment Name                                          Assignment 2
# Course Name                               Introduction to Art History
# Content             Introduc on to Art History Assignment 2 Classi...
# Assignment Type                                                 Essay
# Difficulty_Level                                                    2
# Name: 1, dtype: object

# %%
def get_llm_response(prompt, temperature=0.1):
    try:
        responses = model.generate_content(
            [prompt],
            generation_config={
                "max_output_tokens": 2048,
                "temperature": temperature,
                "top_p": 1
            },
            stream=True,
        )
        
        full_response = ""
        for response in responses:
            if hasattr(response, 'text'):
                full_response += response.text
                print(response.text, end="")
            else:
                print(f"Unexpected response format: {response}")
        
        if not full_response:
            print("Warning: Empty response from LLM")
        
        return full_response.strip() if full_response else None
    except Exception as e:
        print(f"Error in get_llm_response: {e}")
        return None

# %%
def estimate_completion_time(row, llm_function):
    prompt = f"""
    Based on the following assignment details, estimate the time (in hours) it would take an average student to complete the assignment. Restrict time estimation for each assignment to a maximum of 8 hours and do not go above the time limit. Be very brief in your response and briefly explain the reasons. 

    Assignment Name: {row['Assignment Name']}
    Course: {row['Course Name']}
    Content: {row['Content']}
    Assignment Type: {row['Assignment Type']}
    Difficulty Level: {row['Difficulty_Level']} (on a scale of 1-3, where 3 is most difficult)
    
    Please provide your estimate as a single number representing hours. For example: 5.5
    """
    
    print(f"Sending prompt for assignment: {row['Assignment Name']}")
    response = llm_function(prompt)
    print(f"Received response: {response}")
    
    if response is None:
        print(f"No response received from LLM for assignment: {row['Assignment Name']}")
        return float('nan')
    
    try:
        # Extract the first number from the response
        import re
        numbers = re.findall(r'\d+(?:\.\d+)?', response)
        if numbers:
            estimated_time = float(numbers[0])
            return estimated_time
        else:
            print(f"No numeric estimate found in LLM response for assignment: {row['Assignment Name']}")
            return float('nan')
    except ValueError as e:
        print(f"Error parsing time estimate from LLM response for assignment: {row['Assignment Name']}. Error: {e}")
        return float('nan')

# %%
df['Time_Completion'] = df.apply(estimate_completion_time, axis=1, args=(get_llm_response,))
# Out:
# Sending prompt for assignment: Assignment 1
# ## Estimated Time: 6.5 hours
#
# **Explanation:**
#
# * **Research:** 2.5 hours
#     * Researching the key features and religious beliefs reflected in Mesopotamian art.
#     * Researching the main characteristics and role of art in Egyptian burial practices.
#     * Researching the art of the Indus Valley and comparing/contrasting it with Mesopotamian and Egyptian art.
# * **Writing:** 3 hours
#     * Writing a well-structured essay with a clear introduction, body paragraphs addressing each question, and a conclusion.
#     * Ensuring proper citations and referencing of sources.
# * **Review and Editing:** 1 hour
#     * Proofreading for grammar, spelling, and clarity.
#     * Ensuring the essay adheres to the assignment guidelines and rubric.
#
# **Note:** This is an estimated time based on the average student. Individual times may vary depending on research skills, writing speed, and familiarity with the subject matter.
# Received response: ## Estimated Time: 6.5 hours
#
# **Explanation:**
#
# * **Research:** 2.5 hours
#     * Researching the key features and religious beliefs reflected in Mesopotamian art.
#     * Researching the main characteristics and role of art in Egyptian burial practices.
#     * Researching the art of the Indus Valley and comparing/contrasting it with Mesopotamian and Egyptian art.
# * **Writing:** 3 hours
#     * Writing a well-structured essay with a clear introduction, body paragraphs addressing each question, and a conclusion.
#     * Ensuring proper citations and referencing of sources.
# * **Review and Editing:** 1 hour
#     * Proofreading for grammar, spelling, and clarity.
#     * Ensuring the essay adheres to the assignment guidelines and rubric.
#
# **Note:** This is an estimated time based on the average student. Individual times may vary depending on research skills, writing speed, and familiarity with the subject matter.
# Sending prompt for assignment: Assignment 2
# ## Estimated Time: 6.5 hours
#
# **Explanation:**
#
# * **Content:** The essay covers a broad range of topics within Greek and Roman art, including sculpture, architecture, and painting. Analyzing the evolution of these art forms across different periods requires research and critical thinking.
# * **Difficulty Level:**  A difficulty level of 2 suggests the assignment requires moderate understanding and analysis of the subject matter. This likely involves engaging with scholarly sources and formulating well-supported arguments.
# * **Assignment Type:**  Essays typically demand more time than other assignment types due to the need for research, organization, writing, and revision.
# * **Estimated Time Breakdown:**
#     * Research: 2 hours
#     * Writing: 3 hours
#     * Revision and Editing: 1.5 hours
#
# **Note:** This is an estimated time based on the information provided. Individual student completion times may vary depending on their research skills, writing proficiency, and familiarity with the subject matter.
# Received response: ## Estimated Time: 6.5 hours
#
# **Explanation:**
#
# * **Content:** The essay covers a broad range of topics within Greek and Roman art, including sculpture, architecture, and painting. Analyzing the evolution of these art forms across different periods requires research and critical thinking.
# * **Difficulty Level:**  A difficulty level of 2 suggests the assignment requires moderate understanding and analysis of the subject matter. This likely involves engaging with scholarly sources and formulating well-supported arguments.
# * **Assignment Type:**  Essays typically demand more time than other assignment types due to the need for research, organization, writing, and revision.
# * **Estimated Time Breakdown:**
#     * Research: 2 hours
#     * Writing: 3 hours
#     * Revision and Editing: 1.5 hours
#
# **Note:** This is an estimated time based on the information provided. Individual student completion times may vary depending on their research skills, writing proficiency, and familiarity with the subject matter.
# Sending prompt for assignment: Assignment 3
# ## Time Estimation for Assignment 3: Introduction to Art History
#
# **Estimated Time:** 6.5 hours
#
# **Explanation:**
#
# * **Content:** The assignment covers three distinct artistic styles (Byzantine, Romanesque, and Gothic) within the Middle Ages, requiring research and understanding of each style's characteristics, influences, and notable examples.
# * **Question Complexity:** The questions delve into specific features, differences, and evolution of each style, demanding analysis and critical thinking.
# * **Difficulty Level:**  The assignment is classified as having a "3" difficulty level, indicating a higher level of complexity compared to other assignments in the course.
# * **Assignment Type:**  An essay requires research, organization, writing, and proofreading, which can be time-consuming.
#
# **Breakdown:**
#
# * Research: 2.5 hours (gathering information on each style, key features, examples)
# * Analysis and Writing: 3 hours (understanding the questions, formulating arguments, writing clear and concise answers)
# * Proofreading and Editing: 1 hour (ensuring clarity, coherence, and proper grammar)
#
# **Note:** This is an estimated time based on the information provided. Individual student times may vary depending on their research skills, writing speed, and familiarity with the subject matter.
# Received response: ## Time Estimation for Assignment 3: Introduction to Art History
#
# **Estimated Time:** 6.5 hours
#
# **Explanation:**
#
# * **Content:** The assignment covers three distinct artistic styles (Byzantine, Romanesque, and Gothic) within the Middle Ages, requiring research and understanding of each style's characteristics, influences, and notable examples.
# * **Question Complexity:** The questions delve into specific features, differences, and evolution of each style, demanding analysis and critical thinking.
# * **Difficulty Level:**  The assignment is classified as having a "3" difficulty level, indicating a higher level of complexity compared to other assignments in the course.
# * **Assignment Type:**  An essay requires research, organization, writing, and proofreading, which can be time-consuming.
#
# **Breakdown:**
#
# * Research: 2.5 hours (gathering information on each style, key features, examples)
# * Analysis and Writing: 3 hours (understanding the questions, formulating arguments, writing clear and concise answers)
# * Proofreading and Editing: 1 hour (ensuring clarity, coherence, and proper grammar)
#
# **Note:** This is an estimated time based on the information provided. Individual student times may vary depending on their research skills, writing speed, and familiarity with the subject matter.
# Sending prompt for assignment: Assignment 1
# ## Estimated Time to Complete Assignment 1: 6.5 hours
#
# **Explanation:**
#
# * **Data Download and Exploration (0.5 hours):** Downloading the dataset and getting familiar with its structure and variables should take around 30 minutes.
# * **Descriptive Analysis (1.5 hours):** Calculating and interpreting key statistics like mean, median, standard deviation, etc., for different variables could take around 1.5 hours.
# * **Segmentation Analysis (2 hours):** Identifying and describing customer segments using techniques like k-means clustering or decision trees could take around 2 hours.
# * **Predictive Analysis (1.5 hours):** Building a model to predict future sales using techniques like linear regression or decision trees could take around 1.5 hours. This includes data preparation, model training, and evaluation.
# * **Visualization (1 hour):** Creating visualizations to support the analysis, such as bar charts, scatter plots, and heatmaps, could take around 1 hour.
# * **Report Writing (1 hour):** Writing a report summarizing the findings, including introduction, methodology, results, discussion, and conclusion, could take around 1 hour.
#
# **Assumptions:**
#
# * The student has a basic understanding of marketing analytics concepts and techniques.
# * The student has experience with data analysis tools like Excel or Python.
# * The provided dataset is relatively clean and well-structured.
#
# **Note:** This is just an estimate, and the actual time required may vary depending on the student's individual skills and experience.
# Received response: ## Estimated Time to Complete Assignment 1: 6.5 hours
#
# **Explanation:**
#
# * **Data Download and Exploration (0.5 hours):** Downloading the dataset and getting familiar with its structure and variables should take around 30 minutes.
# * **Descriptive Analysis (1.5 hours):** Calculating and interpreting key statistics like mean, median, standard deviation, etc., for different variables could take around 1.5 hours.
# * **Segmentation Analysis (2 hours):** Identifying and describing customer segments using techniques like k-means clustering or decision trees could take around 2 hours.
# * **Predictive Analysis (1.5 hours):** Building a model to predict future sales using techniques like linear regression or decision trees could take around 1.5 hours. This includes data preparation, model training, and evaluation.
# * **Visualization (1 hour):** Creating visualizations to support the analysis, such as bar charts, scatter plots, and heatmaps, could take around 1 hour.
# * **Report Writing (1 hour):** Writing a report summarizing the findings, including introduction, methodology, results, discussion, and conclusion, could take around 1 hour.
#
# **Assumptions:**
#
# * The student has a basic understanding of marketing analytics concepts and techniques.
# * The student has experience with data analysis tools like Excel or Python.
# * The provided dataset is relatively clean and well-structured.
#
# **Note:** This is just an estimate, and the actual time required may vary depending on the student's individual skills and experience.
# Sending prompt for assignment: Assignment 2
# ## Time Estimation for Assignment 2: Marketing Analytics
#
# **Estimated Time:** 6.5 hours
#
# **Explanation:**
#
# * **Data Download and Exploration (0.5 hours):** Downloading the dataset and getting familiar with its structure and variables should take around 30 minutes.
# * **Market Basket Analysis (1.5 hours):** Performing the analysis, identifying product associations, and interpreting the results could take approximately 1.5 hours, considering the complexity of the analysis and the need for visualization.
# * **Customer Lifetime Value Analysis (2 hours):** Calculating CLV for different customer segments, interpreting the results, and potentially comparing segments would require around 2 hours due to the calculations involved and the need for clear explanations.
# * **Sentiment Analysis (1.5 hours):** Analyzing customer reviews, gauging sentiment, and visualizing the findings could take around 1.5 hours, depending on the size and complexity of the review data.
# * **Report Writing and Visualization (1 hour):** Writing the executive summary, data overview, methodology, and key findings sections could take around 30 minutes. Creating visualizations to support the findings and writing the strategic recommendations and conclusion sections could take another 30 minutes.
# * **Advanced Techniques (0.5 hours):**  Applying advanced marketing analytics concepts and techniques could add an additional 30 minutes to the overall time.
#
# **Note:** This is an estimated time based on the information provided. The actual time required may vary depending on the student's individual skills and experience with marketing analytics tools and techniques.
# Received response: ## Time Estimation for Assignment 2: Marketing Analytics
#
# **Estimated Time:** 6.5 hours
#
# **Explanation:**
#
# * **Data Download and Exploration (0.5 hours):** Downloading the dataset and getting familiar with its structure and variables should take around 30 minutes.
# * **Market Basket Analysis (1.5 hours):** Performing the analysis, identifying product associations, and interpreting the results could take approximately 1.5 hours, considering the complexity of the analysis and the need for visualization.
# * **Customer Lifetime Value Analysis (2 hours):** Calculating CLV for different customer segments, interpreting the results, and potentially comparing segments would require around 2 hours due to the calculations involved and the need for clear explanations.
# * **Sentiment Analysis (1.5 hours):** Analyzing customer reviews, gauging sentiment, and visualizing the findings could take around 1.5 hours, depending on the size and complexity of the review data.
# * **Report Writing and Visualization (1 hour):** Writing the executive summary, data overview, methodology, and key findings sections could take around 30 minutes. Creating visualizations to support the findings and writing the strategic recommendations and conclusion sections could take another 30 minutes.
# * **Advanced Techniques (0.5 hours):**  Applying advanced marketing analytics concepts and techniques could add an additional 30 minutes to the overall time.
#
# **Note:** This is an estimated time based on the information provided. The actual time required may vary depending on the student's individual skills and experience with marketing analytics tools and techniques.
# Sending prompt for assignment: Assignment 3
# ## Time Estimation for Marketing Analytics Assignment 3
#
# **Estimated Time:** 7.5 hours
#
# **Explanation:**
#
# * **Reviewing the case study:** 0.5 hours (assuming familiarity with basic marketing concepts)
# * **Market Segmentation:** 1.5 hours (data exploration, clustering analysis, interpretation)
# * **Sales Forecasting:** 2 hours (data preparation, model building, evaluation, interpretation)
# * **Marketing Mix Modeling:** 2 hours (data preparation, model building, evaluation, interpretation)
# * **Customer Churn Analysis:** 1.5 hours (data preparation, model building, evaluation, interpretation)
# * **Visualization and Report Writing:** 2 hours (creating visualizations, writing report sections)
# * **Presentation Preparation:** 0.5 hours (condensing report, creating slides)
#
# **Reasoning:**
#
# * The assignment involves multiple complex analyses, requiring significant time for data exploration, model building, and interpretation.
# * Difficulty level is high, indicating potentially challenging tasks and requiring more time for problem-solving.
# * Visualization and report writing demand careful attention to detail and clarity, contributing to the overall time commitment.
#
# **Note:** This is an estimated time based on the information provided. Individual student times may vary depending on their experience, skills, and working pace.
# Received response: ## Time Estimation for Marketing Analytics Assignment 3
#
# **Estimated Time:** 7.5 hours
#
# **Explanation:**
#
# * **Reviewing the case study:** 0.5 hours (assuming familiarity with basic marketing concepts)
# * **Market Segmentation:** 1.5 hours (data exploration, clustering analysis, interpretation)
# * **Sales Forecasting:** 2 hours (data preparation, model building, evaluation, interpretation)
# * **Marketing Mix Modeling:** 2 hours (data preparation, model building, evaluation, interpretation)
# * **Customer Churn Analysis:** 1.5 hours (data preparation, model building, evaluation, interpretation)
# * **Visualization and Report Writing:** 2 hours (creating visualizations, writing report sections)
# * **Presentation Preparation:** 0.5 hours (condensing report, creating slides)
#
# **Reasoning:**
#
# * The assignment involves multiple complex analyses, requiring significant time for data exploration, model building, and interpretation.
# * Difficulty level is high, indicating potentially challenging tasks and requiring more time for problem-solving.
# * Visualization and report writing demand careful attention to detail and clarity, contributing to the overall time commitment.
#
# **Note:** This is an estimated time based on the information provided. Individual student times may vary depending on their experience, skills, and working pace.
# Sending prompt for assignment: Assignment 4
# ## Time Estimation for Assignment 4: Marketing Analytics
#
# **Estimated Time:** 25 hours
#
# **Explanation:**
#
# * **Problem Selection and Data Collection (4 hours):** Choosing a relevant problem, identifying data sources, and collecting data can be time-consuming, especially for students unfamiliar with the field.
# * **Data Cleaning and Preparation (5 hours):**  Cleaning and preparing data for analysis often requires significant effort, especially for large or messy datasets.
# * **Exploratory Data Analysis (4 hours):**  Exploring the data to understand its structure and identify patterns can be an iterative process, requiring time to visualize and interpret results.
# * **Hypothesis Testing (4 hours):** Formulating and testing hypotheses requires careful consideration and statistical analysis, potentially involving multiple iterations.
# * **Predictive Modeling (4 hours):** Building and evaluating predictive models can be complex, depending on the chosen techniques and data complexity.
# * **Optimization Analysis (2 hours):** Identifying optimal strategies based on analysis might involve additional calculations and comparisons.
# * **Visualization and Reporting (6 hours):** Creating clear and informative visualizations and writing a comprehensive report can be time-consuming, requiring careful attention to detail and effective communication.
# * **Presentation Preparation (1 hour):**  Preparing a clear and concise presentation summarizing key findings and recommendations requires effective synthesis and communication skills.
#
# **Note:** This is an estimated time based on the information provided. The actual time required may vary depending on the student's individual skills, experience, and chosen problem complexity.
# Received response: ## Time Estimation for Assignment 4: Marketing Analytics
#
# **Estimated Time:** 25 hours
#
# **Explanation:**
#
# * **Problem Selection and Data Collection (4 hours):** Choosing a relevant problem, identifying data sources, and collecting data can be time-consuming, especially for students unfamiliar with the field.
# * **Data Cleaning and Preparation (5 hours):**  Cleaning and preparing data for analysis often requires significant effort, especially for large or messy datasets.
# * **Exploratory Data Analysis (4 hours):**  Exploring the data to understand its structure and identify patterns can be an iterative process, requiring time to visualize and interpret results.
# * **Hypothesis Testing (4 hours):** Formulating and testing hypotheses requires careful consideration and statistical analysis, potentially involving multiple iterations.
# * **Predictive Modeling (4 hours):** Building and evaluating predictive models can be complex, depending on the chosen techniques and data complexity.
# * **Optimization Analysis (2 hours):** Identifying optimal strategies based on analysis might involve additional calculations and comparisons.
# * **Visualization and Reporting (6 hours):** Creating clear and informative visualizations and writing a comprehensive report can be time-consuming, requiring careful attention to detail and effective communication.
# * **Presentation Preparation (1 hour):**  Preparing a clear and concise presentation summarizing key findings and recommendations requires effective synthesis and communication skills.
#
# **Note:** This is an estimated time based on the information provided. The actual time required may vary depending on the student's individual skills, experience, and chosen problem complexity.
# Sending prompt for assignment: Assignment 1
# ## Estimated Time: 4.5 hours
#
# **Explanation:**
#
# * **Calculating basic descriptive statistics:** 0.5 hours (Relatively straightforward calculations)
# * **Creating a frequency distribution table:** 0.5 hours (Simple counting and organization)
# * **Generating and interpreting boxplots and histograms:** 1.5 hours (Requires understanding of the concepts and using software/tools)
# * **Calculating and interpreting standard deviation and variance:** 1 hour (Slightly more complex calculations and interpretation)
# * **Writing and formatting the Word document:** 1 hour (Assuming basic writing and formatting skills)
#
# **Total:** 4.5 hours
#
# **Note:** This is an estimate for an average student. Individual times may vary depending on factors such as prior knowledge, software proficiency, and writing speed.
# Received response: ## Estimated Time: 4.5 hours
#
# **Explanation:**
#
# * **Calculating basic descriptive statistics:** 0.5 hours (Relatively straightforward calculations)
# * **Creating a frequency distribution table:** 0.5 hours (Simple counting and organization)
# * **Generating and interpreting boxplots and histograms:** 1.5 hours (Requires understanding of the concepts and using software/tools)
# * **Calculating and interpreting standard deviation and variance:** 1 hour (Slightly more complex calculations and interpretation)
# * **Writing and formatting the Word document:** 1 hour (Assuming basic writing and formatting skills)
#
# **Total:** 4.5 hours
#
# **Note:** This is an estimate for an average student. Individual times may vary depending on factors such as prior knowledge, software proficiency, and writing speed.
# Sending prompt for assignment: Assignment 2
# ## Estimated Time: 6.5 hours
#
# **Explanation:**
#
# * **Calculating probabilities using combinations and permutations (1 hour):** This task involves understanding basic probability concepts and applying formulas. While the calculations themselves might be straightforward, grasping the underlying concepts could take some time for an average student.
# * **Understanding and applying binomial, Poisson, and normal distributions (3 hours):** This task requires a deeper understanding of different types of distributions and their properties. Students will need to study the characteristics of each distribution, learn how to apply them to real-world scenarios, and interpret the results.
# * **Solving problems related to probability distributions and interpreting the results (2.5 hours):** Applying the knowledge gained in the previous tasks to solve problems will require careful analysis and interpretation of the results. This might involve setting up the problem correctly, choosing the appropriate distribution, performing calculations, and drawing conclusions based on the findings.
#
# **Total estimated time:** 1 hour + 3 hours + 2.5 hours = **6.5 hours**
#
# **Note:** This is just an estimate, and the actual time required may vary depending on the individual student's background knowledge, learning pace, and problem-solving skills.
# Received response: ## Estimated Time: 6.5 hours
#
# **Explanation:**
#
# * **Calculating probabilities using combinations and permutations (1 hour):** This task involves understanding basic probability concepts and applying formulas. While the calculations themselves might be straightforward, grasping the underlying concepts could take some time for an average student.
# * **Understanding and applying binomial, Poisson, and normal distributions (3 hours):** This task requires a deeper understanding of different types of distributions and their properties. Students will need to study the characteristics of each distribution, learn how to apply them to real-world scenarios, and interpret the results.
# * **Solving problems related to probability distributions and interpreting the results (2.5 hours):** Applying the knowledge gained in the previous tasks to solve problems will require careful analysis and interpretation of the results. This might involve setting up the problem correctly, choosing the appropriate distribution, performing calculations, and drawing conclusions based on the findings.
#
# **Total estimated time:** 1 hour + 3 hours + 2.5 hours = **6.5 hours**
#
# **Note:** This is just an estimate, and the actual time required may vary depending on the individual student's background knowledge, learning pace, and problem-solving skills.
# Sending prompt for assignment: Assignment 3
# ## Time Estimation: 7.5 hours
#
# **Explanation:**
#
# * **Hypothesis testing (t-tests, chi-square tests):** This section likely involves multiple tests and interpreting results, taking around 3 hours.
# * **Confidence intervals:** Calculating and interpreting confidence intervals for different scenarios could take approximately 1.5 hours.
# * **ANOVA analysis:** Performing ANOVA with multiple comparisons and interpreting the results could take around 2 hours.
# * **Detailed calculations and interpretations:** Writing detailed calculations and interpretations for each section could take around 1 hour.
# * **Submission preparation:** Formatting the Word document and ensuring all required elements are included could take around 30 minutes.
#
# **Total estimated time:** 3 hours (hypothesis testing) + 1.5 hours (confidence intervals) + 2 hours (ANOVA) + 1 hour (calculations/interpretations) + 0.5 hours (submission) = **7.5 hours**
#
# **Note:** This is an estimate based on the information provided. The actual time required may vary depending on the student's individual abilities and the complexity of the specific problems.
# Received response: ## Time Estimation: 7.5 hours
#
# **Explanation:**
#
# * **Hypothesis testing (t-tests, chi-square tests):** This section likely involves multiple tests and interpreting results, taking around 3 hours.
# * **Confidence intervals:** Calculating and interpreting confidence intervals for different scenarios could take approximately 1.5 hours.
# * **ANOVA analysis:** Performing ANOVA with multiple comparisons and interpreting the results could take around 2 hours.
# * **Detailed calculations and interpretations:** Writing detailed calculations and interpretations for each section could take around 1 hour.
# * **Submission preparation:** Formatting the Word document and ensuring all required elements are included could take around 30 minutes.
#
# **Total estimated time:** 3 hours (hypothesis testing) + 1.5 hours (confidence intervals) + 2 hours (ANOVA) + 1 hour (calculations/interpretations) + 0.5 hours (submission) = **7.5 hours**
#
# **Note:** This is an estimate based on the information provided. The actual time required may vary depending on the student's individual abilities and the complexity of the specific problems.
# Sending prompt for assignment: Assignment 4
# ## Estimated Time: 5.5 hours
#
# **Explanation:**
#
# * **Performing regressions:** This typically takes around 2 hours, considering data exploration and model building for both simple and multiple linear regressions.
# * **Interpreting coefficients:** Analyzing and explaining the meaning of coefficients, along with R-squared and p-values, can take approximately 1.5 hours.
# * **Creating and interpreting residual plots:** Generating and interpreting residual plots to assess model assumptions and identify potential issues might take around 1 hour.
# * **Writing and formatting:** Writing a clear and concise report with interpretations and conclusions, including formatting and referencing, could take another 1 hour.
#
# **Note:** This is an estimated time based on the information provided. The actual time may vary depending on the student's individual abilities and experience with statistical analysis.
# Received response: ## Estimated Time: 5.5 hours
#
# **Explanation:**
#
# * **Performing regressions:** This typically takes around 2 hours, considering data exploration and model building for both simple and multiple linear regressions.
# * **Interpreting coefficients:** Analyzing and explaining the meaning of coefficients, along with R-squared and p-values, can take approximately 1.5 hours.
# * **Creating and interpreting residual plots:** Generating and interpreting residual plots to assess model assumptions and identify potential issues might take around 1 hour.
# * **Writing and formatting:** Writing a clear and concise report with interpretations and conclusions, including formatting and referencing, could take another 1 hour.
#
# **Note:** This is an estimated time based on the information provided. The actual time may vary depending on the student's individual abilities and experience with statistical analysis.

# %%
df
# Out:
#    Assignment Name                  Course Name  \
# 0     Assignment 1  Introduction to Art History
# 1     Assignment 2  Introduction to Art History
# 2     Assignment 3  Introduction to Art History
# 3     Assignment 1          Marketing Analytics
# 4     Assignment 2          Marketing Analytics
# 5     Assignment 3          Marketing Analytics
# 6     Assignment 4          Marketing Analytics
# 7     Assignment 1         Statistical Analysis
# 8     Assignment 2         Statistical Analysis
# 9     Assignment 3         Statistical Analysis
# 10    Assignment 4         Statistical Analysis
#
#                                               Content Assignment Type  \
# 0   Introduc on to Art History Assignment 1 Early ...           Essay
# 1   Introduc on to Art History Assignment 2 Classi...           Essay
# 2   Introduc on to Art History Assignment 3 The Mi...           Essay
# 3   Marketing Analytics Assignment 1 Introduc on W...          Coding
# 4   Marketing Analytics Assignment 2 Introduc on W...          Coding
# 5   Marketing Analytics Assignment 3 Introduc on W...          Coding
# 6   Marketing Analytics Assignment 4 Introduc on W...          Coding
# 7   Statistical Analysis Assignment 1 Objec ve Und...     Problem Set
# 8   Statistical Analysis Assignment 2 Objec ve Exp...     Problem Set
# 9   Statistical Analysis Assignment 3 Objec ve Lea...     Problem Set
# 10  Statistical Analysis Assignment 4 Objec ve Und...     Problem Set
#
#     Difficulty_Level  Time_Completion
# 0                  2              6.5
# 1                  2              6.5
# 2                  3              3.0
# 3                  2              1.0
# 4                  3              2.0
# 5                  3              3.0
# 6                  3              4.0
# 7                  1              4.5
# 8                  2              6.5
# 9                  3              7.5
# 10                 2              5.5

# %%
# write to pickle

import pandas as pd

time_completion = df[['Time_Completion']]

file_path = './time_completion.pkl'
time_completion.to_pickle(file_path)

# %%
df_new = pd.read_pickle("time_completion.pkl")

# %%
df["Time_Completion"][7]
# Out:
# 4.5
